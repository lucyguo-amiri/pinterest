# %%
import pandas as pd 
import numpy as np
df = pd.read_csv("pinterest_country_historical.csv")
df.head()
# Out:
#          date country   campaign_id  checkout_value  checkout_value_micro  \
# 0  2025-09-03      US  626755902381          1090.0          1.090000e+09
# 1  2025-09-03      US  626755902620             NaN                   NaN
# 2  2025-09-03      US  626755902689           890.0          8.900000e+08
# 3  2025-09-04      US  626755902381          1980.0          1.980000e+09
# 4  2025-09-04      US  626755902620             NaN                   NaN
#
#    checkouts  clicks  conversions  impressions       spend  spend_micro  \
# 0        1.0    44.0        857.0          NaN  118.678555  118678555.0
# 1        NaN    82.0        207.0          NaN   51.022034   51022034.0
# 2        1.0   106.0        504.0          NaN  258.453689  258453689.0
# 3        2.0    45.0        651.0          NaN   96.296127   96296127.0
# 4        NaN    38.0         82.0          NaN   20.089779   20089779.0
#
#   date_range_start date_range_end  CAMPAIGN_NAME                campaign_name  \
# ...

# %%
df.groupby(["date", "campaign_name"])[["checkout_value", "checkouts", "clicks", "impressions", "spend"]].sum()
# Out:
#                                              checkout_value  checkouts  \
# date       campaign_name
# 2025-09-03 TNT_AWR_Prospecting_Traffic                  0.0        0.0
#            TNT_CVR_Prospecting_Catalog                890.0        1.0
#            TNT_CVR_Retargeting_Catalog               1090.0        1.0
# 2025-09-04 TNT_AWR_Prospecting_Traffic                  0.0        0.0
#            TNT_CVR_Prospecting_Catalog                  0.0        0.0
# ...                                                     ...        ...
# 2025-11-29 TNT_CVR_Retargeting_SiteVisitors           590.0        1.0
# 2025-11-30 TNT_CVR_Retargeting_Catalog                  0.0        0.0
#            TNT_CVR_Retargeting_SiteVisitors             0.0        0.0
# 2025-12-01 TNT_CVR_Retargeting_Catalog                  0.0        0.0
#            TNT_CVR_Retargeting_SiteVisitors             0.0        0.0
#
#                                              clicks  impressions       spend
# ...

# %%
df[df.date == '2025-11-29']
# Out:
#           date country   campaign_id  checkout_value  checkout_value_micro  \
# 65  2025-11-29      US  626755499613           590.0           590000000.0
# 66  2025-11-29      US  626755902381           750.0           750000000.0
#
#     checkouts  clicks  conversions  impressions  spend  spend_micro  \
# 65        1.0    34.0        248.0          NaN  375.0  375000000.0
# 66        1.0    80.0        829.0          NaN  125.0  125000000.0
#
#    date_range_start date_range_end  CAMPAIGN_NAME  \
# 65       2025-09-03     2025-12-01            NaN
# 66       2025-09-03     2025-12-01            NaN
#
#                        campaign_name  IMPRESSION_1
# 65  TNT_CVR_Retargeting_SiteVisitors        5717.0
# 66       TNT_CVR_Retargeting_Catalog       14135.0
